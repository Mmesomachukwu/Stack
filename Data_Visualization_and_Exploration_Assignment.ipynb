# %% [markdown]
# <a href="https://colab.research.google.com/github/Mmesomachukwu/Stack/blob/master/Data_Visualization_and_Exploration_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6e3d29a8-616c-4e6a-b7a8-77abcf64e4e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e3d29a8-616c-4e6a-b7a8-77abcf64e4e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# ref                                                        title                                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------  --------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/top-spotify-songs-2023                    Most Streamed Spotify Songs 2023               47KB  2023-08-26 11:04:57          23312        709  1.0
# iamsouravbanerjee/customer-shopping-trends-dataset         Customer Shopping Trends Dataset              146KB  2023-10-05 06:45:37            900         34  1.0
# willianoliveiragibin/diabetesdataanslysis                  diabetesDataAnslysis                            9KB  2023-09-27 19:54:22            801         24  1.0
# ...

# %%
# !kaggle datasets download joebeachcapital/world-population-by-country-2023
# Out:
# ...
#   0% 0.00/8.04k [00:00<?, ?B/s]
# 100% 8.04k/8.04k [00:00<00:00, 19.2MB/s]

# %%
from zipfile import ZipFile
with ZipFile("/content/world-population-by-country-2023.zip", "r") as myZip:
  myZip.extractall("/content")

# %%
import pandas as pd

df = pd.read_csv("/content/WorldPopulation2023.csv")
df.head()
# Out:
#    Rank         Country  Population2023 YearlyChange  NetChange  \
# 0    36     Afghanistan        42239854       2.70 %    1111083
# 1   138         Albania         2832439      -0.35 %      -9882
# 2    34         Algeria        45606480       1.57 %     703255
# 3   212  American Samoa           43914      -0.81 %       -359
# 4   202         Andorra           80088       0.33 %        264
#
#    Density(P/Km²)  Land Area(Km²)  Migrants(net)  Fert.Rate  MedianAge  \
# 0              65          652860         -65846        4.4       17.0
# 1             103           27400          -8000        1.4       38.0
# 2              19         2381740          -9999        2.8       28.0
# 3             220             200           -790        2.2       29.0
# 4             170             470            200        1.1       43.0
#
#   UrbanPop% WorldShare
# 0      26 %     0.53 %
# 1      67 %     0.04 %
# 2      75 %     0.57 %
# 3      N.A.     0.00 %
# 4      85 %     0.00 %
